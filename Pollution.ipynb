# %%
import pandas as pd

# %%
f2015 = pd.read_csv('/Users/piyushbhatia/Desktop/Pollution/NagpurPollution2015.csv')

# %%
f2015.columns
# Out:
# Index([u'Stn Code', u'Sampling Date', u'State', u'City\/Town\/Village\/Area',
#        u'Location of Monitoring Station', u'Agency', u'Type of Location',
#        u'SO2', u'NO2', u'RSPM\/PM10', u'PM 2.5'],
#       dtype='object')

# %%
f2015.columns = ['Stn Code','Sampling Date','State', 'Area',
       'Location of Monitoring Station', 'Agency', 'Type of Location',
       'SO2', 'NO2', 'RSPM/PM10', 'PM 2.5']

# %%
f2015.head()
# Out:
#    Stn Code Sampling Date        State    Area  \
# 0       165      02-01-15  Maharashtra  Nagpur
# 1       165      09-01-15  Maharashtra  Nagpur
# 2       165      12-01-15  Maharashtra  Nagpur
# 3       165      23-01-15  Maharashtra  Nagpur
# 4       165      28-01-15  Maharashtra  Nagpur
#
#                      Location of Monitoring Station  \
# 0  MIDC Industrial Area, MIDC Office, Hingna,Nagpur
# 1  MIDC Industrial Area, MIDC Office, Hingna,Nagpur
# 2  MIDC Industrial Area, MIDC Office, Hingna,Nagpur
# 3  MIDC Industrial Area, MIDC Office, Hingna,Nagpur
# 4  MIDC Industrial Area, MIDC Office, Hingna,Nagpur
#
#                                               Agency Type of Location    SO2  \
# 0  National Environmental Engineering Research In...  Industrial Area   16.0
# 1  National Environmental Engineering Research In...  Industrial Area   23.0
# 2  National Environmental Engineering Research In...  Industrial Area   25.0
# ...

# %%
f2015['Type of Location'].unique()
# Out:
# array(['Industrial Area', 'Residential, Rural and other Areas',
#        'Sensitive Area'], dtype=object)

# %%
f2015.drop('State', axis=1)
# Out:
#       Stn Code Sampling Date    Area  \
# 0          165      02-01-15  Nagpur
# 1          165      09-01-15  Nagpur
# 2          165      12-01-15  Nagpur
# 3          165      23-01-15  Nagpur
# 4          165      28-01-15  Nagpur
# 5          165      30-01-15  Nagpur
# 6          165      02-02-15  Nagpur
# 7          165      06-02-15  Nagpur
# 8          165      09-02-15  Nagpur
# 9          165      13-02-15  Nagpur
# 10         165      16-02-15  Nagpur
# 11         165      20-02-15  Nagpur
# 12         165      23-02-15  Nagpur
# 13         165      03-03-15  Nagpur
# 14         165      09-03-15  Nagpur
# 15         165      11-03-15  Nagpur
# 16         165      13-03-15  Nagpur
# 17         165      14-03-15  Nagpur
# 18         165      16-03-15  Nagpur
# 19         165      21-03-15  Nagpur
# 20         165      24-03-15  Nagpur
# 21         165      27-03-15  Nagpur
# 22         165      03-04-15  Nagpur
# 23         165      07-04-15  Nagpur
# ...

# %%
f2015.describe()
# Out:
#           Stn Code          SO2          NO2    RSPM/PM10  PM 2.5
# count  6994.000000  6707.000000  6929.000000  6969.000000     0.0
# mean    507.154847    16.065305    34.234522   101.015784     NaN
# std     169.438108    13.176956    20.321009    48.390057     NaN
# min     165.000000     1.000000     2.000000     3.000000     NaN
# 25%     314.000000     8.000000    19.000000    66.000000     NaN
# 50%     511.000000    13.000000    31.000000    97.000000     NaN
# 75%     648.000000    20.000000    45.000000   128.000000     NaN
# max     711.000000   184.000000   167.000000   660.000000     NaN

# %%
int(f2015.SO2.mean())
# Out:
# 16

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(f2015.NO2)

# %%
g = sns.PairGrid(data=f2015)
g.map(plt.scatter)
